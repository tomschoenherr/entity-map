# %%
import pandas as pd
from splink.exploratory import completeness_chart
from splink import DuckDBAPI, block_on
from splink import SettingsCreator, Linker
import splink.comparison_library as cl
from splink.blocking_analysis import (
    cumulative_comparisons_to_be_scored_from_blocking_rules_chart,
)
import numpy as np
db_api = DuckDBAPI()

# %% [markdown]
# # Load Datasets

# %%
a_clean = pd.read_pickle("data/a_clean")
a_clean = a_clean.replace('', pd.NA)
a_clean.head()
# Out:
#        unique_id    parent_id       top_id  cnt_children  orgtype_id  geo_id  \
# 9651    18802368          NaN   18802368.0             0           0  100239
# 67057   18802818  288468727.0  288468696.0             0           0   34197
# 31323   18802831          NaN   18802831.0             2           0       0
# 22669   18804109  156221130.0  288468696.0             0           0    4502
# 18784   18883986   47362264.0   47362264.0             0           0   58834
#
#                                    name email phone  fax  ...       region  \
# 9651   lohberger engineering pty ltdsjf   NaN   NaN  NaN  ...          NaN
# 67057                   lockheed martin   NaN   NaN  NaN  ...      midwest
# 31323                             logus   NaN   NaN  NaN  ...  not_defined
# 22669                   lockheed martin   NaN   NaN  NaN  ...         <NA>
# 18784                           lugokdc   NaN   NaN  NaN  ...         <NA>
#
#               division congress_district congress_land_area country_y  \
# 9651               NaN               NaN                NaN       usa
# 67057          central                02             243791       usa
# 31323      not_defined       not_defined        not_defined       usa
# 22669  middle atlantic              0103          350028997       usa
# 18784          pacific            080910    735971834382667       usa
#
#       continent iso  zipcode  address_number   street_name
# 9651    america  us      NaN             NaN           NaN
# 67057   america  us    55121             NaN         eagan
# 31323   america  us    34409             NaN    palm beach
# 22669   america  us    08057             NaN    moorestown
# 18784   america  us    98424            5210  12th cfifewa
#
# [5 rows x 48 columns]

# %%
b_clean = pd.read_pickle("data/b_clean")
b_clean.head()
# Out:
#    unique_id parent_id   top_id            name entity_proper_name  \
# 0    000bfge       NaN  000bfge         lotsoff             lotoff
# 14   000ff7e       NaN  000ff7e          legacy             legacy
# 7    000fjle       NaN  000fjle     leadingside        leadingside
# 15   000hnqe       NaN  000hnqe  lci industries     lci industries
# 16   000hnwe   05hjcve  05hjcve       lasercard          lasercard
#
#     primary_sic_code  industry_code  sector_code iso_country_x  \
# 0             5331.0         3520.0       3500.0            us
# 14            7819.0         3430.0       3400.0            us
# 7             7371.0         3308.0       3300.0            us
# 15            3716.0         1250.0       1200.0            us
# 16            3695.0         1315.0       1300.0            us
#
#                metro_area  ... fax_area      fax     fax_full   hq  \
# 0     san antoniotx metro  ...      NaN      NaN          NaN  1.0
# 14  san franciscoca metro  ...      310  4173500  13104173500  1.0
# 7          bostonma metro  ...      NaN      NaN          NaN  1.0
# 15        chicagoil metro  ...      NaN      NaN          NaN  1.0
# 16  san franciscoca metro  ...      650  9693140  16509693140  1.0
#
#               address  iso state    zipcode  address_number      street_name
# 0     1201 austin 116   us    tx  782094859            1201       austin 116
# 14           4160 4th   us    ca      94538            4160              4th
# 7   1 canal park 3300   us    ma      02141               1  canal park 3300
# 15      3501 county 6   us    in      46514            3501         county 6
# 16     1875 shoreline   us    ca      94043            1875        shoreline
#
# [5 rows x 43 columns]

# %% [markdown]
# # Visualize completeness for column selection

# %%
completeness_chart(a_clean, db_api=db_api)
# Out:
# alt.LayerChart(...)

# %%
completeness_chart(b_clean, db_api=db_api)
# Out:
# alt.LayerChart(...)

# %%
used_columns = ['unique_id', 'name', 'iso', 'state', 'city', 'zipcode', 'address_number', 'street_name', 'websiteurl', 'area_code']

a_used = a_clean[used_columns]
a_used.head(50)
# Out:
#        unique_id                                 name iso        state  \
# 9651    18802368     lohberger engineering pty ltdsjf  us          NaN
# 67057   18802818                      lockheed martin  us           mn
# 31323   18802831                                logus  us  not_defined
# 22669   18804109                      lockheed martin  us           nj
# 18784   18883986                              lugokdc  us           wa
# 9397    18884006              lockheed martin gyrocam  us         <NA>
# 20023   18885103             l3 global communications  us           ny
# 72198   18889982                   levin professional  us           md
# 21208   18890128                           lepier oil  us           mn
# 3401    18890131                      linc government  us           ky
# 13903   18890248                    l3 communications  us           tx
# 52638   18890314                    lone star pavment  us           tx
# 5738    18890351                    los angeles foods  us           ca
# 28272   18890523                               lawson  us           il
# 13574   18890765                   life of leadership  us           nv
# 36528   18890919                       lotek wireless  ca      ontario
# 42255   18891008                   leica microsystems  us           il
# 28156   18891031                  lockheed martin ms2  us           nj
# 30581   18891332                    layne christensen  us           tx
# 21347   18908201                      lockheed martin  us           az
# 12053   18908231                      lockheed martin  us           md
# 1103    18908234                      lockheed martin  us         <NA>
# 17589   18908391                        lobo ventures  us           tx
# 43968   18908641                       lego education  us           ks
# 44179   18908644                                 lord  us           pa
# 14367   18908687                        linear motion  us           mi
# 15401   18908769                       lbb associates  us           md
# 31379   18908948                               laurus  us           md
# 6203    18909177                      lilly tree farm  us           il
# 15059   18909758     livingstone general construction  us           ca
# 17637   18909830                                  lee  us           ca
# 19216   18914626                    l3 communications  us           ga
# 42544   18914911  lewis sound and video professionals  us           wi
# 22720   18915023                    l3 communications  us           nj
# 43389   18915292          lt engineering construction  us           md
# 31674   18915357                            luminator  us           tx
# 29733   18915934                            logistics  us           va
# 32358   18928857                      lockheed martin  us  not_defined
# 23162   18946910                        leggett platt  us           il
# 6761    18946943                logistics engineering  us           md
# 890     18947216                             la foods  us  not_defined
# 30201   18947312                  learning associates  us           il
# 48177   18947317                    luther consulting  us           in
# 48548   18947454                      lockheed martin  us         <NA>
# 67169   18947538                                  lrk  us           ia
# 31199   18947782                                 loos  us         <NA>
# 17752   18948445                      liberty roofing  us           az
# 19853   18949309                        l c engineers  us           nj
# 26197   18949408          laucks testing laboratories  us          NaN
# 15247   18949454                                   l3  us           ia
#
#                  city zipcode address_number  \
# 9651              NaN     NaN            NaN
# 67057      saint paul   55121            NaN
# 31323     not_defined   34409            NaN
# 22669      moorestown   08057            NaN
# 18784          tacoma   98424           5210
# 9397         sarasota   34243           7345
# 20023          victor   14564           7640
# 72198   silver spring   20902            NaN
# 21208         fosston   56542            320
# 3401     hopkinsville   42240            101
# 13903         garland   75041           3414
# 52638          conroe   77385          27045
# 5738      canoga park   91303           7301
# 28272     des plaines   60018           1666
# 13574       las vegas   89120            NaN
# 36528       newmarket  l3y7b5            115
# 42255       deerfield   60015           2345
# 28156      moorestown   08057            199
# 30581          spring   77380           1800
# 21347        goodyear   85338            NaN
# 12053    gaithersburg   20879            700
# 1103         colorado   80921            NaN
# 17589     san antonio   78216            NaN
# 43968       pittsburg   66762            917
# 44179            erie   16514           1635
# 14367         saginaw   48602            NaN
# 15401        columbia   21046           9891
# 31379   ellicott city   21043           3460
# 6203             mode   62444            NaN
# 15059     kelseyville   95451            NaN
# 17637  marina del rey   90292            NaN
# 19216      alpharetta   30004           1355
# 42544        waukesha   53186           2325
# 22720       budd lake   07828            NaN
# 43389      sykesville   21784            NaN
# 31674           plano   75074            NaN
# 29733         mc lean   22102           2000
# 32358     not_defined   22110            NaN
# 23162        sandoval   62882            NaN
# 6761        annapolis   21409           1356
# 890       not_defined   31270            NaN
# 30201      naperville   60563           1120
# 48177    indianapolis   46204            423
# 48548         oldsmar   34677            NaN
# 67169      sioux city   51101            545
# 31199         pomfret   06258            NaN
# 17752        lakeside   85929           5758
# 19853          rahway   07065            NaN
# 26197             NaN     NaN            NaN
# 15247        riverton   51650            200
#
#                                              street_name  \
# 9651                                                 NaN
# 67057                                              eagan
# 31323                                         palm beach
# 22669                                         moorestown
# 18784                                       12th cfifewa
# 9397                                  16th 101sarasotafl
# 20023                                    omnitech victor
# 72198         washington prof 11242 grandview wheaton md
# 21208                                        1st fosston
# 3401                                 walton hopkinsville
# 13903                               herrmann drgarlandtx
# 52638                                              hanna
# 5738                      topanga canyon 200 canoga park
# 28272                                              touhy
# 13574     dba rapport leadership 5715 sandhill las vegas
# 36528                                               pony
# 42255                               waukegan bannockburn
# 28156                                  borton moorestown
# 30581                                         hughes 700
# 21347  lockheed martin information global 1300 litchf...
# 12053                          frederick gaithersburg md
# 1103       lockheed martin information global 9970 loc a
# 17589                                  ltd12027 warfield
# 43968                                jefferson pittsburg
# 44179                                  12th streeet erie
# 14367              linear motion 628 hamilton saginaw mi
# 15401                        broken land 400 columbia md
# 31379                                       ellicott 101
# 6203                                   rr 1 box 179 mode
# 15059                            po box 1477 kelseyville
# 17637                                       burkhart liu
# 19216                          bluegrass lakes alphretta
# 42544                                           parklawn
# 22720           l3 communications 450 clark budd lake nj
# 43389  lt engineering construction 6330 carroll park ...
# 31674                       luminator 900 klein plano tx
# 29733                                          corporate
# 32358                                           manassas
# 23162                                leggett610 illinois
# 6761                           cape claire rdannapolismd
# 890    los angeles foods la foods 7301 topanga canyon...
# 30201                               diehl 200 naperville
# 48177                      massachusetts indianapolis in
# 48548                 lockheed martin 3655 tampa oldsmar
# 67169                                           chambers
# 31199                  loos junction 101 and 169 pomfret
# 17752                         white mountain lakeside az
# 19853                                             rahway
# 26197                                                NaN
# 15247                           los angeles simi ca 9306
#
#                                       websiteurl area_code
# 9651                                         NaN       NaN
# 67057                   httpwwwlockheedmartincom       651
# 31323                                        NaN       not
# 22669                                        NaN       856
# 18784                                        NaN       253
# 9397   httpwwwgyrocamsystemscomcgibinext_redirpl       941
# 20023                                        NaN       585
# 72198                                        NaN       301
# 21208                                        NaN       218
# 3401                                         NaN       270
# 13903                                        NaN       972
# 52638                                        NaN       281
# 5738                                         NaN       818
# 28272                          lawsonproductscom       847
# 13574                                        NaN       702
# 36528                            httpwwwlotekcom       cao
# 42255                httpwwwleicamicrosystemscom       847
# 28156                                        NaN       856
# 30581                            httpwwwlaynecom       281
# 21347                                        NaN       623
# 12053                   httpwwwlockheedmartincom       301
# 1103                                         NaN       719
# 17589                                        NaN       210
# 43968                                        NaN       620
# 44179                                        NaN       814
# 14367                                        NaN       989
# 15401                                        NaN       410
# 31379                    httpwwwlaurussystemscom       410
# 6203                                         NaN       217
# 15059                                        NaN       707
# 17637                                        NaN       310
# 19216                                        NaN       770
# 42544                                        NaN       262
# 22720                                        NaN       973
# 43389                                        NaN       410
# 31674                                        NaN       972
# 29733                              httpwwwlmiorg       703
# 32358                   httpwwwlockheedmartincom       not
# 23162                                        NaN       618
# 6761                                         NaN       410
# 890                                          NaN       not
# 30201                                        NaN       630
# 48177                                        NaN       317
# 48548                                        NaN       813
# 67169                                        NaN       712
# 31199                           httpwwwlooscocom       860
# 17752                                        NaN       928
# 19853                      httpwwwlcengineerscom       732
# 26197                                        NaN       NaN
# 15247                                        NaN       712

# %%
b_used = b_clean[used_columns]
b_used.head(50)
# Out:
#     unique_id                               name  iso state          city  \
# 0     000bfge                            lotsoff   us    tx   san antonio
# 14    000ff7e                             legacy   us    ca       fremont
# 7     000fjle                        leadingside   us    ma     cambridge
# 15    000hnqe                     lci industries   us    in       elkhart
# 16    000hnwe                          lasercard   us    ca      mountain
# 19    000jf6e                            longwen   us    az    scottsdale
# 3     000jp9e                       leonardo spa   it                rome
# 6     000l15e                            lisi sa   fr    fc       belfort
# 22    000ny4e                      lumara health   us    mo  chesterfield
# 8     000ny7e                            la gear   us    ca   los angeles
# 9     000ny8e                     la quinta inns   us    tx   san antonio
# 10    000ny9e               la quinta motor inns   us    tx   san antonio
# 11    000nybe                           la z boy   us    mi        monroe
# 13    000nyce                            labarge   us    mo         louis
# 33    000nyde                         labone old   us    ks           NaN
# 34    000nyfe              laboratory of america   us    nc    burlington
# 35    000nyge                        laclede gas   us    mo         louis
# 36    000nyhe                      laclede steel   us    mo         louis
# 44    000nyje                  lacrosse footwear   us    or      portland
# 56    000nyke                 la z boy casegoods   us    mi       raleigh
# 57    000nyle                      ladysmith iga   us   NaN           NaN
# 58    000nyme                      ladysmith iga   us   NaN           NaN
# 64    000nyne                    lafarge america   us    il       chicago
# 66    000nype                   laidlaw covenant   us    ny           NaN
# 67    000nyqe                             laifer   us    ny           NaN
# 77    000nyre                 lake ariel bancorp   us    pa    lake ariel
# 80    000nyse                               lake   us   NaN           NaN
# 81    000nyte                 lake shore bancorp   us    ny       dunkirk
# 97    000nyve                           lakeland   us    in        warsaw
# 98    000nywe                lakeland industries   us    ny      new york
# 105   000nyxe                           lakeside   us    ga           NaN
# 107   000nyze                                lam   us    ca       fremont
# 108   000nz0e             lambert communications   us   NaN           NaN
# 117   000nz2e                             lamcor   us    mn      le sueur
# 125   000nz3e                    lamonts apparel   us    wa      kirkland
# 126   000nz4e                    lamson sessions   us    oh     beachwood
# 128   000nz5e                   lancaster colony   us    oh   westerville
# 137   000nz6e                              lance   us    nc     charlotte
# 138   000nz7e                             lancer   us    tx   san antonio
# 139   000nz8e                lancer orthodontics   us    ca         vista
# 147   000nzbe                           landauer   us    il      glenwood
# 148   000nzhe          legg mason partners money   us    ny      new york
# 149   000nzje                  landmark graphics   us    tx       houston
# 155   000nzke     landmark institutional funds i  NaN   NaN           NaN
# 157   000nzle  legg mason partners institutional   us    ny      new york
# 158   000nzme         legg mason partners global   us   NaN           NaN
# 166   000nzpe  legg mason partners premium money   us    ny      new york
# 169   000nzte                            landrys   us    tx       houston
# 170   000nzve                          lands end   us    wi    dodgeville
# 178   000nzwe                   landsing pacific   us    ca     san mateo
#
#        zipcode address_number                       street_name  \
# 0    782094859           1201                        austin 116
# 14       94538           4160                               4th
# 7        02141              1                   canal park 3300
# 15       46514           3501                          county 6
# 16       94043           1875                         shoreline
# 19       85258           7702              doubletree ranch 300
# 3        00195            NaN             piazza monte grappa 4
# 6        90000            NaN  le millenium 18 rue albert camus
# 22       63005          16640                  chesterfield 200
# 8        90049            844                            moraga
# 9    782992636            NaN           weston centre 112 pecan
# 10       78299            NaN                  guest assistance
# 11       48162           1284                         telegraph
# 13       63124           9900                           clayton
# 33       66214            NaN                               NaN
# 34   272155837            358                              main
# 35       63101            NaN                               720
# 36       63102            440                           4th 300
# 44       97230          17634                           airport
# 56       48162            160                     mine lake 200
# 57         NaN            NaN                               NaN
# 58         NaN            NaN                               NaN
# 64       60631           8700                     bryn mawr 300
# 66         NaN            NaN                               NaN
# 67         NaN            NaN                               NaN
# 77       18436            NaN                               NaN
# 80         NaN            NaN                               NaN
# 81   140482226             31                               4th
# 97   465811387            NaN                               202
# 98   117799010           3555    veterans memorial c ronkonkoma
# 105      31061            NaN                               NaN
# 107      94538           4650                           cushing
# 108        NaN            NaN                               NaN
# 117      56058            NaN                               169
# 125      98034          12413                           willows
# 126  441227313          25701                      science park
# 128      43082            380                       polaris 400
# 137      28277          13024          ballantyne corporate 900
# 138      78219           6655                            lancer
# 139      92081           1493                    poinsettia 143
# 147  604251586              2                           science
# 148      10041             55                             water
# 149      77094            333                    cyress run 100
# 155        NaN            NaN                               NaN
# 157      10041             55                             water
# 158        NaN            NaN                               NaN
# 166      10041             55                             water
# 169      77027            NaN                              1510
# 170      53595              1                         lands end
# 178      94402            155                         bovet 101
#
#                      websiteurl area_code
# 0                           NaN       210
# 14                          NaN       510
# 7                           NaN       617
# 15               httpwwwlci1com       574
# 16          httpwwwlasercardcom       650
# 19                          NaN       480
# 3     httpwwwleonardocompanycom        06
# 6           httpwwwlisigroupcom         3
# 22                          NaN       314
# 8              httpwwwlagearcom       310
# 9                           NaN       NaN
# 10                          NaN       NaN
# 11             httpwwwlazboycom       734
# 13            httpwwwlabargecom       314
# 33                          NaN       NaN
# 34            httpwwwlabcorpcom       336
# 35         httpwwwlacledegascom       314
# 36                          NaN       314
# 44   httpwwwlacrossefootwearcom       800
# 56       httpwwwlzbcasegoodscom       NaN
# 57                          NaN       NaN
# 58                          NaN       NaN
# 64          httpwwwlafargenacom       773
# 66                          NaN       NaN
# 67                          NaN       NaN
# 77                          NaN       NaN
# 80                          NaN       NaN
# 81   httpwwwlakeshoresavingscom       716
# 97       httpwwwlakecitybankcom       574
# 98           httpwwwlakelandcom       631
# 105                         NaN       NaN
# 107       httpwwwlamresearchcom       510
# 108                         NaN       NaN
# 117                         NaN       NaN
# 125                         NaN       425
# 126                         NaN       NaN
# 128   httpwwwlancastercolonycom       614
# 137             httpwwwlancecom       704
# 138        httpwwwlancercorpcom       888
# 139       httpwwwlancerorthocom       760
# 147          httpwwwlandauercom       708
# 148                         NaN       800
# 149                         NaN       NaN
# 155                         NaN       NaN
# 157                         NaN       800
# 158                         NaN       NaN
# 166                         NaN       800
# 169        httpwwwlandrysinccom       713
# 170          httpwwwlandsendcom       608
# 178                         NaN       NaN

# %% [markdown]
# # Determine Blocking Methodology

# %% [markdown]
# From these plots, I can see that the following variables appear to be good candidates:
# - iso would make a good blocking variable
# - company name comparison is key
# - comparing addresses might give more information (although a lot of data is missing)
# - city, state, and zip code are also missing information but still might be useful

# %% [markdown]
# What do I want to see from blocking rules?
# - < 10M added comparisons for each block
# - Compare highly specific blocks first, then move to more generalized blocks

# %%
blocking_rules = [

    # Highly specific blocks
    block_on("zipcode", "area_code"),
    block_on("state", "city", "area_code"),
    block_on("state", "city"),
    block_on("name", "iso"),
    block_on("street_name", "iso"),

    # Moderately specific blocks
    block_on("state", "area_code"),
    block_on("city", "area_code"),       
    block_on("city"),                    
    block_on("zipcode"),


    # General fallback blocks
    block_on("LEFT(zipcode, 3)"),
    block_on("area_code"),
    block_on("LEFT(name, 8)", "iso"),
]

cumulative_comparisons_to_be_scored_from_blocking_rules_chart(
    table_or_tables=[a_used, b_used],
    blocking_rules=blocking_rules,
    db_api=db_api,
    link_type="link_only"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Initialize Linkage Model

# %%
p_2_records = 1/np.min([a_used.shape[0], b_used.shape[0]])
settings = SettingsCreator(
    link_type = "link_only",
    blocking_rules_to_generate_predictions=blocking_rules,
    comparisons=[
        cl.JaroWinklerAtThresholds("name", score_threshold_or_thresholds=[0.92, 0.88, 0.7]),
        cl.JaroWinklerAtThresholds("street_name", score_threshold_or_thresholds=[0.92, 0.88, 0.7]),
        cl.DamerauLevenshteinAtThresholds("address_number"),
        cl.JaroAtThresholds('websiteurl'),

        cl.DamerauLevenshteinAtThresholds("zipcode").configure(term_frequency_adjustments=True),
        cl.DamerauLevenshteinAtThresholds("area_code").configure(term_frequency_adjustments=True),
        
        cl.ExactMatch("iso").configure(term_frequency_adjustments=True),

    ],
    retain_intermediate_calculation_columns=True,

    probability_two_random_records_match=p_2_records
)

linker = Linker([a_used, b_used], settings, db_api=db_api)

# %% [markdown]
# # Train Linkage Model

# %%
linker.training.estimate_u_using_random_sampling(max_pairs=1e8)
# Out:
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - name (no m values are trained).
#     - street_name (no m values are trained).
#     - address_number (no m values are trained).
#     - websiteurl (no m values are trained).
#     - zipcode (no m values are trained).
#     - area_code (no m values are trained).
#     - iso (no m values are trained).

# %%
training_blocking_rule = block_on("state", "city")
training_session_geo = (
    linker.training.estimate_parameters_using_expectation_maximisation(training_blocking_rule)
)
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."state" = r."state") AND (l."city" = r."city")
#
# Parameter estimates will be made for the following comparison(s):
#     - name
#     - street_name
#     - address_number
#     - websiteurl
#     - zipcode
#     - area_code
#     - iso
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#
# Iteration 1: Largest change in params was -0.677 in the m_probability of name, level `Exact match on name`
# Iteration 2: Largest change in params was 0.68 in the m_probability of street_name, level `All other comparisons`
# Iteration 3: Largest change in params was 0.502 in probability_two_random_records_match
# Iteration 4: Largest change in params was 0.246 in probability_two_random_records_match
# Iteration 5: Largest change in params was 0.0689 in probability_two_random_records_match
# Iteration 6: Largest change in params was 0.0315 in probability_two_random_records_match
# Iteration 7: Largest change in params was 0.0154 in probability_two_random_records_match
# Iteration 8: Largest change in params was 0.0075 in probability_two_random_records_match
# Iteration 9: Largest change in params was 0.00365 in probability_two_random_records_match
# Iteration 10: Largest change in params was 0.00177 in probability_two_random_records_match
# Iteration 11: Largest change in params was 0.000854 in probability_two_random_records_match
# Iteration 12: Largest change in params was 0.000417 in probability_two_random_records_match
# Iteration 13: Largest change in params was 0.00028 in probability_two_random_records_match
# Iteration 14: Largest change in params was 0.000235 in probability_two_random_records_match
# Iteration 15: Largest change in params was 0.000127 in probability_two_random_records_match
# Iteration 16: Largest change in params was 6.62e-05 in probability_two_random_records_match
#
# EM converged after 16 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
training_blocking_rule = block_on("zipcode")
training_session_zipcode = linker.training.estimate_parameters_using_expectation_maximisation(
    training_blocking_rule
)
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l."zipcode" = r."zipcode"
#
# Parameter estimates will be made for the following comparison(s):
#     - name
#     - street_name
#     - address_number
#     - websiteurl
#     - area_code
#     - iso
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - zipcode
#
# Iteration 1: Largest change in params was 0.31 in probability_two_random_records_match
# Iteration 2: Largest change in params was 0.317 in probability_two_random_records_match
# Iteration 3: Largest change in params was 0.106 in probability_two_random_records_match
# Iteration 4: Largest change in params was 0.0344 in probability_two_random_records_match
# Iteration 5: Largest change in params was -0.0212 in the m_probability of area_code, level `Exact match on area_code`
# Iteration 6: Largest change in params was -0.0146 in the m_probability of area_code, level `Exact match on area_code`
# Iteration 7: Largest change in params was -0.0087 in the m_probability of area_code, level `Exact match on area_code`
# Iteration 8: Largest change in params was -0.00492 in the m_probability of area_code, level `Exact match on area_code`
# Iteration 9: Largest change in params was -0.00273 in the m_probability of area_code, level `Exact match on area_code`
# Iteration 10: Largest change in params was -0.00151 in the m_probability of area_code, level `Exact match on area_code`
# Iteration 11: Largest change in params was -0.000845 in the m_probability of area_code, level `Exact match on area_code`
# Iteration 12: Largest change in params was -0.000479 in the m_probability of area_code, level `Exact match on area_code`
# Iteration 13: Largest change in params was -0.000277 in the m_probability of area_code, level `Exact match on area_code`
# Iteration 14: Largest change in params was -0.000164 in the m_probability of area_code, level `Exact match on area_code`
# Iteration 15: Largest change in params was -9.99e-05 in the m_probability of area_code, level `Exact match on area_code`
#
# EM converged after 15 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
training_blocking_rule = block_on("area_code")
training_session_areacode = linker.training.estimate_parameters_using_expectation_maximisation(
    training_blocking_rule
)
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l."area_code" = r."area_code"
#
# Parameter estimates will be made for the following comparison(s):
#     - name
#     - street_name
#     - address_number
#     - websiteurl
#     - zipcode
#     - iso
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - area_code
#
# Iteration 1: Largest change in params was -0.226 in the m_probability of zipcode, level `All other comparisons`
# Iteration 2: Largest change in params was 0.231 in the m_probability of zipcode, level `Damerau-Levenshtein distance of zipcode <= 2`
# Iteration 3: Largest change in params was 0.0207 in probability_two_random_records_match
# Iteration 4: Largest change in params was 0.0096 in the m_probability of zipcode, level `All other comparisons`
# Iteration 5: Largest change in params was 0.0147 in the m_probability of zipcode, level `All other comparisons`
# Iteration 6: Largest change in params was 0.0215 in the m_probability of zipcode, level `All other comparisons`
# Iteration 7: Largest change in params was 0.0295 in the m_probability of zipcode, level `All other comparisons`
# Iteration 8: Largest change in params was 0.0378 in the m_probability of zipcode, level `All other comparisons`
# Iteration 9: Largest change in params was 0.0447 in the m_probability of zipcode, level `All other comparisons`
# Iteration 10: Largest change in params was 0.0484 in the m_probability of zipcode, level `All other comparisons`
# Iteration 11: Largest change in params was 0.0481 in the m_probability of zipcode, level `All other comparisons`
# Iteration 12: Largest change in params was 0.0441 in the m_probability of zipcode, level `All other comparisons`
# Iteration 13: Largest change in params was 0.0375 in the m_probability of zipcode, level `All other comparisons`
# Iteration 14: Largest change in params was 0.0301 in the m_probability of zipcode, level `All other comparisons`
# Iteration 15: Largest change in params was 0.023 in the m_probability of zipcode, level `All other comparisons`
# Iteration 16: Largest change in params was 0.0181 in probability_two_random_records_match
# Iteration 17: Largest change in params was 0.0136 in probability_two_random_records_match
# Iteration 18: Largest change in params was 0.00994 in probability_two_random_records_match
# Iteration 19: Largest change in params was 0.00707 in probability_two_random_records_match
# Iteration 20: Largest change in params was 0.00495 in probability_two_random_records_match
# Iteration 21: Largest change in params was 0.00342 in probability_two_random_records_match
# Iteration 22: Largest change in params was 0.00234 in probability_two_random_records_match
# Iteration 23: Largest change in params was 0.00159 in probability_two_random_records_match
# Iteration 24: Largest change in params was 0.00108 in probability_two_random_records_match
# Iteration 25: Largest change in params was 0.000732 in probability_two_random_records_match
#
# EM converged after 25 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
linker.visualisations.match_weights_chart()
# Out:
# alt.VConcatChart(...)

# %%
linker.evaluation.unlinkables_chart()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Predict using trained model

# %%
predictions = linker.inference.predict()
pred_df = predictions.as_pandas_dataframe()
pred_df.head()
# Out:
# Blocking time: 11.08 seconds
# Predict time: 19.13 seconds
#    match_weight  match_probability         source_dataset_l  \
# 0     -3.334911           0.090168  __splink__input_table_0
# 1     -9.106291           0.001811  __splink__input_table_0
# 2     -2.589175           0.142500  __splink__input_table_0
# 3     -5.055099           0.029201  __splink__input_table_0
# 4     -0.495859           0.414910  __splink__input_table_0
#
#           source_dataset_r unique_id_l unique_id_r                     name_l  \
# 0  __splink__input_table_1   156280820     0dtrwme                  lou moody
# 1  __splink__input_table_1   156280913     061sl0e         lou marks and sons
# 2  __splink__input_table_1   156280941     0081wqe        laughlin industries
# 3  __splink__input_table_1   156281340     003jhge  leonard parker associates
# 4  __splink__input_table_1   156281398     0g798ce              locks gallery
#
#                              name_r  gamma_name   bf_name  ... gamma_iso  \
# 0                      cold storage           0  0.972405  ...         1
# 1                     louisville of           0  0.972405  ...         1
# 2  lighthouse document technologies           0  0.972405  ...         1
# 3                       larsonallen           0  0.972405  ...         1
# 4                        locust wny           0  0.972405  ...         1
#
#    tf_iso_l  tf_iso_r    bf_iso bf_tf_adj_iso state_l  state_r        city_l  \
# 0  0.503065  0.503065  3.086101      0.643988      tx       tx   san antonio
# 1  0.503065  0.503065  3.086101      0.643988      ky       ky    louisville
# 2  0.503065  0.503065  3.086101      0.643988      wa       wa       seattle
# 3  0.503065  0.503065  3.086101      0.643988      mn       mn   minneapolis
# 4  0.503065  0.503065  3.086101      0.643988      pa       pa  philadelphia
#
#          city_r match_key
# 0   san antonio         1
# 1    louisville         1
# 2       seattle         1
# 3   minneapolis         1
# 4  philadelphia         1
#
# [5 rows x 48 columns]

# %%
records_to_view = predictions.as_record_dict(limit=30)
linker.visualisations.waterfall_chart(records_to_view, filter_nulls=False)
# Out:
# alt.LayerChart(...)

# %%
def filter_highest_match_probability(pred_df):

    # Sort by unique_id_l and match_probability (descending)
    sorted_df = pred_df.sort_values(['unique_id_l', 'match_probability'], 
                                   ascending=[True, False])
    
    # Keep only the first row (highest probability) for each unique_id_l
    filtered_df = sorted_df.groupby('unique_id_l').first().reset_index()
    
    return filtered_df

# %%
filtered_predictions = filter_highest_match_probability(pred_df)
filtered_predictions.head(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 filtered_predictions = filter_highest_match_probability(pred_df)
#       2 filtered_predictions.head(100)
#
# NameError: name 'filter_highest_match_probability' is not defined
